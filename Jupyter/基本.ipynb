# %%
# 导入 pandas 库
import pandas as pd

# %%
# 创建 Series 对象
surname = pd.Series(['赵', '钱', '孙', '李'])
# 查看surname
surname
# Out:
# 0    赵
# 1    钱
# 2    孙
# 3    李
# dtype: object

# %%
# 创建 Series 对象 人爲設定索引
surname = pd.Series(['赵', '钱', '孙', '李'], index = ['学生1', '学生2', '学生3', '学生4'])
# 查看surname
surname
# Out:
# 学生1    赵
# 学生2    钱
# 学生3    孙
# 学生4    李
# dtype: object

# %%
# 创建 Series 对象
players = pd.Series(['梅西','罗本','C罗'])
# 查看 players
players
# Out:
# 0    梅西
# 1    罗本
# 2    C罗
# dtype: object

# %%
# n維數組
import numpy as np
array = pd.Series(np.array([1,2]))
array
# Out:
# 0    1
# 1    2
# dtype: int32

# %%
# Series對象下列表相加方法
# 创建两个原始列表
temp_list1 = [1, 2, 3, 4]
temp_list2 = [5, 6, 2, 3]
# 创建新的 Series 对象
temps = pd.Series(temp_list1)+pd.Series(temp_list2)
temps
# Out:
# 0    6
# 1    8
# 2    5
# 3    7
# dtype: int64

# %%
# 创建 DataFrame 对象，鍵值長度要相等
new_df = pd.DataFrame({'年龄': [23, 22, 21],
                       '岗位': ['客服', '运营', '公关'],
                       '年购买量': [10, 15, 8]})
# 查看 new_df
new_df
# Out:
#    年龄  岗位  年购买量
# 0  23  客服    10
# 1  22  运营    15
# 2  21  公关     8

# %%
# 创建 DataFrame 对象
class_df = pd.DataFrame({'年龄': [25, 18, 23, 18],
                         '性别': ['女', '女', '女', '男']})
# 查看 class_df
class_df
# Out:
#    年龄 性别
# 0  25  女
# 1  18  女
# 2  23  女
# 3  18  男

# %%
# 以n維數組的形式
class_df2 = pd.DataFrame(np.array([[25, '女'],
                                   [18, '女'],
                                   [23, '女'],
                                   [18, '男']]),
                         columns = ['年龄', '性别'],
                         index = [1, 2, 3, 4])
# 查看 class_df2
class_df2
# Out:
#    年龄 性别
# 1  25  女
# 2  18  女
# 3  23  女
# 4  18  男

# %%
# 提取'年龄'这一列数据
class_df['年龄']
# Out:
# 0    25
# 1    18
# 2    23
# 3    18
# Name: 年龄, dtype: int64

# %%
# 查看'年龄'这一列数据的类型
type(class_df['年龄'])
# Out:
# pandas.core.series.Series

# %%
# 导入 csv 数据
my_data = pd.read_csv('mask_data.csv', encoding = 'utf-8')

# %%
my_data
# Out:
#                                订单编号          日期    省          订单量  \
# 0       87af-48e5-8bed-c5dcf9ecc172  2020-01-01   广东          0.0
# 1       535a-4eca-8fa0-9cc54c66e11d  2020-01-01   河南          0.0
# 2       a56d-4415-ad6e-020cdb154c35  2020-01-01   湖北          1.0
# 3       535a-4eca-8fa0-9cc54c66e11d  2020-01-01   河南          0.0
# 4       535a-4eca-8fa0-9cc54c66e11d  2020-01-01   河南          0.0
# ...                             ...         ...  ...          ...
# 101937  6339-43f4-a12b-7b57d1ce3a48         NaN  NaN          NaN
# 101938  5e43-41c2-8696-fd5909cc98a4         NaN  NaN  999999999.0
# 101939  824c-4f2b-af43-038938d2db46         NaN  NaN  999999999.0
# 101940  1cf0-483a-ab11-0cebc6406c78         NaN  NaN          0.0
# 101941  8318-43df-9d34-0656d9eb759a         NaN  NaN          0.0
#
#                  单价          销售额
# 0              30.0          0.0
# 1              30.0          0.0
# 2              30.0         30.0
# 3              30.0          0.0
# 4              30.0          0.0
# ...             ...          ...
# 101937          NaN          NaN
# 101938  999999999.0  999999999.0
# 101939  999999999.0  999999999.0
# 101940          NaN          0.0
# 101941          NaN          0.0
#
# [101942 rows x 6 columns]

# %%
# 读取保单数据
insurance_data = pd.read_csv('保险案例.csv', encoding = 'utf-8')
# 查看保单数据
insurance_data
# Out:
#    客户姓名      渠道         日期  客户年龄 保险类别    保单金额
# 0    张三  传统保险代理   1/1/2020    25   医疗     500
# 1    李四      电销   2/2/2020    34   医疗     600
# 2    王五      银行   3/3/2020    37   重疾     800
# 3    钱海  保险中介平台   2/4/2020    65   人寿   50000
# 4    刘月  传统保险代理   3/5/2020    45   重疾   20000
# 5    曹烈      电销   4/6/2020    40   意外   30000
# 6    王刚      银行   5/1/2020    23   医疗     300
# 7    李洪      电销   6/2/2020    35   医疗     400
# 8    蓝洋  传统保险代理   7/3/2020    67   重疾   50000
# 9    刘峰  传统保险代理   8/4/2020    65   重疾   30000
# 10   李泉  传统保险代理   9/5/2020    34   教育  100000
# 11   张敏  保险中介平台  10/6/2020    56   重疾   30000
# 12   梁幸  保险中介平台  11/6/2020    75   人寿   60000

# %%
my_data.head()
# Out:
#                           订单编号          日期   省  订单量    单价   销售额
# 0  87af-48e5-8bed-c5dcf9ecc172  2020-01-01  广东  0.0  30.0   0.0
# 1  535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南  0.0  30.0   0.0
# 2  a56d-4415-ad6e-020cdb154c35  2020-01-01  湖北  1.0  30.0  30.0
# 3  535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南  0.0  30.0   0.0
# 4  535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南  0.0  30.0   0.0

# %%
my_data.tail()
# Out:
#                                订单编号   日期    省          订单量           单价  \
# 101937  6339-43f4-a12b-7b57d1ce3a48  NaN  NaN          NaN          NaN
# 101938  5e43-41c2-8696-fd5909cc98a4  NaN  NaN  999999999.0  999999999.0
# 101939  824c-4f2b-af43-038938d2db46  NaN  NaN  999999999.0  999999999.0
# 101940  1cf0-483a-ab11-0cebc6406c78  NaN  NaN          0.0          NaN
# 101941  8318-43df-9d34-0656d9eb759a  NaN  NaN          0.0          NaN
#
#                 销售额
# 101937          NaN
# 101938  999999999.0
# 101939  999999999.0
# 101940          0.0
# 101941          0.0

# %%
my_data.tail(10)
# Out:
#                                订单编号   日期    省          订单量           单价  \
# 101932  c64b-45e5-b09a-e070ed9b7c16  NaN  NaN          NaN          NaN
# 101933  cc74-4695-9b6c-ac2571a5d83b  NaN  NaN          NaN          NaN
# 101934  7aaf-4d49-aecf-dd0f04ca0ea4  NaN  NaN          NaN          NaN
# 101935  981f-4b3d-a1eb-5a032814adb6  NaN  NaN          NaN          NaN
# 101936  ad30-4371-a319-17c235c9c67c  NaN  NaN          NaN          NaN
# 101937  6339-43f4-a12b-7b57d1ce3a48  NaN  NaN          NaN          NaN
# 101938  5e43-41c2-8696-fd5909cc98a4  NaN  NaN  999999999.0  999999999.0
# 101939  824c-4f2b-af43-038938d2db46  NaN  NaN  999999999.0  999999999.0
# 101940  1cf0-483a-ab11-0cebc6406c78  NaN  NaN          0.0          NaN
# 101941  8318-43df-9d34-0656d9eb759a  NaN  NaN          0.0          NaN
#
#                 销售额
# 101932          NaN
# 101933          NaN
# 101934          NaN
# 101935          NaN
# 101936          NaN
# 101937          NaN
# 101938  999999999.0
# 101939  999999999.0
# 101940          0.0
# 101941          0.0

# %%
mask_data = my_data

# %%
# 查看 mask_data 的基本信息总结
mask_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101942 entries, 0 to 101941
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   订单编号    101942 non-null  object
#  1   日期      100956 non-null  object
#  2   省       100956 non-null  object
#  3   订单量     100960 non-null  float64
#  4   单价      100958 non-null  float64
#  5   销售额     100960 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 4.7+ MB

# %%
# 查看 mask_data 的缺失值
mask_data.isna()
# Out:
#          订单编号     日期      省    订单量     单价    销售额
# 0       False  False  False  False  False  False
# 1       False  False  False  False  False  False
# 2       False  False  False  False  False  False
# 3       False  False  False  False  False  False
# 4       False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...
# 101937  False   True   True   True   True   True
# 101938  False   True   True  False  False  False
# 101939  False   True   True  False  False  False
# 101940  False   True   True  False   True  False
# 101941  False   True   True  False   True  False
#
# [101942 rows x 6 columns]

# %%
# 查看数据后 5 行
mask_data.tail()
# Out:
#                                订单编号   日期    省          订单量           单价  \
# 101937  6339-43f4-a12b-7b57d1ce3a48  NaN  NaN          NaN          NaN
# 101938  5e43-41c2-8696-fd5909cc98a4  NaN  NaN  999999999.0  999999999.0
# 101939  824c-4f2b-af43-038938d2db46  NaN  NaN  999999999.0  999999999.0
# 101940  1cf0-483a-ab11-0cebc6406c78  NaN  NaN          0.0          NaN
# 101941  8318-43df-9d34-0656d9eb759a  NaN  NaN          0.0          NaN
#
#                 销售额
# 101937          NaN
# 101938  999999999.0
# 101939  999999999.0
# 101940          0.0
# 101941          0.0

# %%
# 删除所有缺失值
mask_data.dropna()
# Out:
#                                订单编号          日期   省   订单量    单价    销售额
# 0       87af-48e5-8bed-c5dcf9ecc172  2020-01-01  广东   0.0  30.0    0.0
# 1       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南   0.0  30.0    0.0
# 2       a56d-4415-ad6e-020cdb154c35  2020-01-01  湖北   1.0  30.0   30.0
# 3       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南   0.0  30.0    0.0
# 4       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南   0.0  30.0    0.0
# ...                             ...         ...  ..   ...   ...    ...
# 100951  8cad-41ee-85b7-c59b85f0ebe6  2020-06-30  湖北  10.0  30.0  300.0
# 100952  4ea4-480a-a070-295408955363  2020-06-30  湖北   6.0  30.0  180.0
# 100953  70f3-4461-9b5f-7f53a55c51b6  2020-06-30  湖北  10.0  30.0  300.0
# 100954  9cc8-4542-8fed-3145e1942504  2020-06-30  湖北  10.0  30.0  300.0
# 100955  f202-45df-96e2-ca4e4c389624  2020-06-30  湖北   5.0  30.0  150.0
#
# [100956 rows x 6 columns]

# %%
# 查看数据基本信息总结
mask_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101942 entries, 0 to 101941
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   订单编号    101942 non-null  object
#  1   日期      100956 non-null  object
#  2   省       100956 non-null  object
#  3   订单量     100960 non-null  float64
#  4   单价      100958 non-null  float64
#  5   销售额     100960 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 4.7+ MB

# %%
# 删除所有缺失值
mask_data = mask_data.dropna()
# 查看数据基本信息总结
mask_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100956 entries, 0 to 100955
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   订单编号    100956 non-null  object
#  1   日期      100956 non-null  object
#  2   省       100956 non-null  object
#  3   订单量     100956 non-null  float64
#  4   单价      100956 non-null  float64
#  5   销售额     100956 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 5.4+ MB

# %%
# 读取练习数据，文件路径为'./工作/test_data.csv'，编码格式为'utf-8'
test_data = pd.read_csv('test_data.csv', encoding='utf-8')
# 查看 test_data
test_data
# Out:
#       Unnamed: 0        ID   品牌           车型  \
# 0              0   54632.0   大众         Golf
# 1              1   46820.0   雷诺  GrandScenic
# 2              2  111350.0  沃尔沃          V40
# 3              3   77294.0   现代         Ix20
# 4              4   24668.0   福特        Focus
# ...          ...       ...  ...          ...
# 9995        9995   30644.0   奔驰         A200
# 9996        9996   69278.0  雪铁龙       Jumper
# 9997        9997    4788.0   奥迪           A4
# 9998        9998   14122.0   宝马          318
# 9999        9999   60203.0   大众      Touareg
#
#                                                    具体型号        上牌时间     马力  \
# 0                       1.2 Tsi Bmt Special Edition 110  2017-01-01   81.0
# 1                 G.Sc�nic 1.5Dci Energy Selection 7Pl.  2016-07-01   81.0
# 2                           D-3 Momentum 150Cv Auto. 5P  2014-03-01  110.0
# 3               1.6 Crdi Bluedrive Comfort 85Kw (115Cv)  2012-12-01   85.0
# 4                                      1.6Tdci Business  2009-12-01   66.0
# ...                                                 ...         ...    ...
# 9995                                       Cdi Be Urban  2015-12-01  100.0
# 9996                                Bluehdi L2H1 Furg�n  2018-02-01   85.0
# 9997              2.0 Tdi Sport Edition 110 Kw (150 Cv)  2016-01-01  110.0
# 9998                                     D Gran Turismo  2016-04-01  110.0
# 9999  Touareg V6 Tdi * Susp. Neumatica * Xenon * Nav...  2013-09-01  180.0
#
#      变速箱类型  燃料   里程数(km)   保值率
# 0       手动  汽油   10000.0  0.54
# 1       手动  柴油   12600.0  0.51
# 2       自动  柴油   93574.0  0.62
# 3       手动  柴油   96000.0  0.66
# 4       手动  柴油  142000.0  0.65
# ...    ...  ..       ...   ...
# 9995    手动  柴油   50000.0  0.68
# 9996    手动  柴油       1.0  0.69
# 9997    手动  柴油       5.0  0.67
# 9998    自动  柴油   35155.0  0.65
# 9999    自动  柴油  125721.0  0.52
#
# [10000 rows x 11 columns]

# %%
# 查看 test_data 的基本信息总结
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   ID          9968 non-null   float64
#  2   品牌          9964 non-null   object
#  3   车型          9968 non-null   object
#  4   具体型号        9968 non-null   object
#  5   上牌时间        9965 non-null   object
#  6   马力          9968 non-null   float64
#  7   变速箱类型       9967 non-null   object
#  8   燃料          9968 non-null   object
#  9   里程数(km)     9905 non-null   float64
#  10  保值率         9999 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 859.5+ KB

# %%
# 删除'品牌'， '上牌时间'， '里程数(km)'， '保值率'四列数据缺失的行
test_data = test_data.dropna(subset=['品牌', '上牌时间', '里程数(km)', '保值率'])
# 查看 test_data 的基本信息总结
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9898 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9898 non-null   int64
#  1   ID          9898 non-null   float64
#  2   品牌          9898 non-null   object
#  3   车型          9898 non-null   object
#  4   具体型号        9898 non-null   object
#  5   上牌时间        9898 non-null   object
#  6   马力          9898 non-null   float64
#  7   变速箱类型       9898 non-null   object
#  8   燃料          9898 non-null   object
#  9   里程数(km)     9898 non-null   float64
#  10  保值率         9898 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 927.9+ KB

# %%
# 查找 mask_data 中的重复行
mask_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 100951    False
# 100952    False
# 100953    False
# 100954    False
# 100955    False
# Length: 100956, dtype: bool

# %%
# 查看 mask_data 中的重复数据
mask_data[mask_data.duplicated()]
# Out:
#                                订单编号          日期   省  订单量    单价    销售额
# 3       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南  0.0  30.0    0.0
# 4       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南  0.0  30.0    0.0
# 412     2b31-4392-be6e-19af71e40261  2020-01-09  河南  1.0  30.0   30.0
# 441     d707-4d5c-ac10-59d3fd3dc0bb  2020-01-10  广东  1.0  30.0   30.0
# 845     49f6-4bd5-97a5-aeb075a1c8c3  2020-01-16  湖北  8.0  40.0  320.0
# ...                             ...         ...  ..  ...   ...    ...
# 100157  1ee1-41a6-8c0a-7c24f988689f  2020-06-25  湖北  8.0  30.0  240.0
# 100312  c72a-401d-8f11-39becb49d442  2020-06-26  湖北  9.0  30.0  270.0
# 100321  73f3-4d40-af4e-426548a7c539  2020-06-26  广东  3.0  30.0   90.0
# 100330  1265-4d27-a5c6-d3d6f44cd594  2020-06-26  广东  3.0  30.0   90.0
# 100772  a56d-4415-ad6e-020cdb154c35  2020-06-29  其他  0.0  30.0    0.0
#
# [448 rows x 6 columns]

# %%
# 直接删除所有重复值
mask_data = mask_data.drop_duplicates()
# 查看 mask_data 中的重复数据
mask_data[mask_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [订单编号, 日期, 省, 订单量, 单价, 销售额]
# Index: []

# %%
# 查看清洗后的基本信息总结
mask_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100508 entries, 0 to 100955
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   订单编号    100508 non-null  object
#  1   日期      100508 non-null  object
#  2   省       100508 non-null  object
#  3   订单量     100508 non-null  float64
#  4   单价      100508 non-null  float64
#  5   销售额     100508 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 5.4+ MB

# %%
# 直接删除 test_data 所有重复行
test_data = test_data.drop_duplicates()
# 查看 test_data 中的重复行
test_data[test_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, 品牌, 车型, 具体型号, 上牌时间, 马力, 变速箱类型, 燃料, 里程数(km), 保值率]
# Index: []

# %%
# 查看口罩厂数据 mask_data 的描述性统计信息
mask_data.describe()
# Out:
#                 订单量            单价           销售额
# count  1.005080e+05  1.005080e+05  1.005080e+05
# mean   9.551786e+05  9.552499e+05  9.592048e+05
# std    3.089086e+07  3.089085e+07  3.089073e+07
# min    0.000000e+00  3.000000e+01  0.000000e+00
# 25%    9.000000e+00  5.000000e+01  5.500000e+02
# 50%    2.000000e+01  5.000000e+01  1.700000e+03
# 75%    4.700000e+01  1.500000e+02  4.000000e+03
# max    1.000000e+09  1.000000e+09  1.000000e+09

# %%
# 查看单价小于等于 200 的数据
mask_data[mask_data['单价'] <= 200]
# Out:
#                                订单编号          日期   省   订单量    单价    销售额
# 0       87af-48e5-8bed-c5dcf9ecc172  2020-01-01  广东   0.0  30.0    0.0
# 1       535a-4eca-8fa0-9cc54c66e11d  2020-01-01  河南   0.0  30.0    0.0
# 2       a56d-4415-ad6e-020cdb154c35  2020-01-01  湖北   1.0  30.0   30.0
# 5       953f-4b46-a8a2-0eb0e39818a8  2020-01-01  其他   0.0  30.0    0.0
# 6       953f-4b46-a8a2-0eb0e39818a8  2020-01-01  湖北   1.0  30.0   30.0
# ...                             ...         ...  ..   ...   ...    ...
# 100951  8cad-41ee-85b7-c59b85f0ebe6  2020-06-30  湖北  10.0  30.0  300.0
# 100952  4ea4-480a-a070-295408955363  2020-06-30  湖北   6.0  30.0  180.0
# 100953  70f3-4461-9b5f-7f53a55c51b6  2020-06-30  湖北  10.0  30.0  300.0
# 100954  9cc8-4542-8fed-3145e1942504  2020-06-30  湖北  10.0  30.0  300.0
# 100955  f202-45df-96e2-ca4e4c389624  2020-06-30  湖北   5.0  30.0  150.0
#
# [100412 rows x 6 columns]

# %%
# 筛选单价小于等于 200 的数据
mask_data = mask_data[mask_data['单价'] <= 200]
# 查看 mask_data 的描述性统计信息
mask_data.describe()
# Out:
#                  订单量             单价            销售额
# count  100412.000000  100412.000000  100412.000000
# mean       30.786529     102.161793    4060.837350
# std        27.639737      63.533396    5278.401132
# min         0.000000      30.000000       0.000000
# 25%         9.000000      50.000000     550.000000
# 50%        20.000000      50.000000    1700.000000
# 75%        47.000000     150.000000    4000.000000
# max       100.000000     200.000000   20000.000000

# %%
# 筛选订单量大于0的数据
mask_data = mask_data[mask_data['订单量'] > 0]
# 查看 mask_data 的描述性统计信息
mask_data.describe()
# Out:
#                 订单量            单价           销售额
# count  99485.000000  99485.000000  99485.000000
# mean      31.073398    102.763130   4098.676182
# std       27.607238     63.486035   5288.293082
# min        1.000000     30.000000     30.000000
# 25%        9.000000     50.000000    560.000000
# 50%       20.000000    100.000000   1750.000000
# 75%       47.000000    150.000000   4000.000000
# max      100.000000    200.000000  20000.000000

# %%
# 转换日期数据，并设置对应的日期格式
date_data = pd.to_datetime(mask_data['日期'], format = '%Y-%m-%d')
# 查看 date_data
date_data
# Out:
# 2        2020-01-01
# 6        2020-01-01
# 11       2020-01-01
# 12       2020-01-01
# 13       2020-01-01
#             ...
# 100951   2020-06-30
# 100952   2020-06-30
# 100953   2020-06-30
# 100954   2020-06-30
# 100955   2020-06-30
# Name: 日期, Length: 99485, dtype: datetime64[ns]

# %%
# 提取日期数据中的月份信息
month_data = date_data.dt.month
# 查看 month_data
month_data
# Out:
# 2         1
# 6         1
# 11        1
# 12        1
# 13        1
#          ..
# 100951    6
# 100952    6
# 100953    6
# 100954    6
# 100955    6
# Name: 日期, Length: 99485, dtype: int64

# %%
# 将月份数据添加到原数据中
mask_data['月份'] = month_data
# 查看原数据
mask_data
# Out:
#                                订单编号          日期   省   订单量    单价    销售额  月份
# 2       a56d-4415-ad6e-020cdb154c35  2020-01-01  湖北   1.0  30.0   30.0   1
# 6       953f-4b46-a8a2-0eb0e39818a8  2020-01-01  湖北   1.0  30.0   30.0   1
# 11      87af-48e5-8bed-c5dcf9ecc172  2020-01-01  湖北   1.0  30.0   30.0   1
# 12      535a-4eca-8fa0-9cc54c66e11d  2020-01-01  湖南   1.0  30.0   30.0   1
# 13      d707-4d5c-ac10-59d3fd3dc0bb  2020-01-01  广东   1.0  30.0   30.0   1
# ...                             ...         ...  ..   ...   ...    ...  ..
# 100951  8cad-41ee-85b7-c59b85f0ebe6  2020-06-30  湖北  10.0  30.0  300.0   6
# 100952  4ea4-480a-a070-295408955363  2020-06-30  湖北   6.0  30.0  180.0   6
# 100953  70f3-4461-9b5f-7f53a55c51b6  2020-06-30  湖北  10.0  30.0  300.0   6
# 100954  9cc8-4542-8fed-3145e1942504  2020-06-30  湖北  10.0  30.0  300.0   6
# 100955  f202-45df-96e2-ca4e4c389624  2020-06-30  湖北   5.0  30.0  150.0   6
#
# [99485 rows x 7 columns]

# %%
# 转换'上牌时间'数据，并设置对应的日期格式
date_test = pd.to_datetime(test_data['上牌时间'], format = '%Y-%m-%d')
# 提取'上牌时间'数据中的年份信息
year_data = date_test.dt.year
# 将年份数据添加到原数据中
test_data['上牌年份'] = year_data
# 查看数据
test_data
# Out:
#       Unnamed: 0        ID   品牌           车型  \
# 0              0   54632.0   大众         Golf
# 1              1   46820.0   雷诺  GrandScenic
# 2              2  111350.0  沃尔沃          V40
# 3              3   77294.0   现代         Ix20
# 4              4   24668.0   福特        Focus
# ...          ...       ...  ...          ...
# 9995        9995   30644.0   奔驰         A200
# 9996        9996   69278.0  雪铁龙       Jumper
# 9997        9997    4788.0   奥迪           A4
# 9998        9998   14122.0   宝马          318
# 9999        9999   60203.0   大众      Touareg
#
#                                                    具体型号        上牌时间     马力  \
# 0                       1.2 Tsi Bmt Special Edition 110  2017-01-01   81.0
# 1                 G.Sc�nic 1.5Dci Energy Selection 7Pl.  2016-07-01   81.0
# 2                           D-3 Momentum 150Cv Auto. 5P  2014-03-01  110.0
# 3               1.6 Crdi Bluedrive Comfort 85Kw (115Cv)  2012-12-01   85.0
# 4                                      1.6Tdci Business  2009-12-01   66.0
# ...                                                 ...         ...    ...
# 9995                                       Cdi Be Urban  2015-12-01  100.0
# 9996                                Bluehdi L2H1 Furg�n  2018-02-01   85.0
# 9997              2.0 Tdi Sport Edition 110 Kw (150 Cv)  2016-01-01  110.0
# 9998                                     D Gran Turismo  2016-04-01  110.0
# 9999  Touareg V6 Tdi * Susp. Neumatica * Xenon * Nav...  2013-09-01  180.0
#
#      变速箱类型  燃料   里程数(km)   保值率  上牌年份
# 0       手动  汽油   10000.0  0.54  2017
# 1       手动  柴油   12600.0  0.51  2016
# 2       自动  柴油   93574.0  0.62  2014
# 3       手动  柴油   96000.0  0.66  2012
# 4       手动  柴油  142000.0  0.65  2009
# ...    ...  ..       ...   ...   ...
# 9995    手动  柴油   50000.0  0.68  2015
# 9996    手动  柴油       1.0  0.69  2018
# 9997    手动  柴油       5.0  0.67  2016
# 9998    自动  柴油   35155.0  0.65  2016
# 9999    自动  柴油  125721.0  0.52  2013
#
# [9898 rows x 12 columns]

# %%
# 保存清洗干净的数据
mask_data.to_csv('mask_data_clean.csv', encoding = 'utf-8', index=False)

# %%
# 导入matplotlib库的pyplot模块
from matplotlib import pyplot as plt
# 设置中文字体
plt.rcParams['font.family'] = ['KaiTi']

# %%
# 创建李健的数据
li_jian = pd.Series([80, 85, 89, 91, 88, 95],
                    index=['2月', '3月', '4月', '5月', '6月', '7月'])
# 查看li_jian
li_jian
# Out:
# 2月    80
# 3月    85
# 4月    89
# 5月    91
# 6月    88
# 7月    95
# dtype: int64

# %%
# 绘制单条折线图
li_jian.plot(kind='line', figsize=(7, 7), title='李健月考成绩')
# Out:
# <AxesSubplot:title={'center':'李健月考成绩'}>

# %%
# 创建三个学生成绩的df
students_grade = pd.DataFrame({'李健': [80, 85, 89, 91, 88, 95],
                               '王聪': [95, 92, 90, 85, 75, 80],
                               '过凡': [90, 91, 92, 91, 90, 91]
                              }, index=['2月', '3月', '4月', '5月', '6月', '7月'])
# 绘制多条折线图
students_grade.plot(kind='line', figsize=(7, 7), title='月考成绩')
# Out:
# <AxesSubplot:title={'center':'月考成绩'}>

# %%
# 餅圖
# 讀取數據
mask_data = pd.read_csv('mask_data_clean.csv', encoding='utf-8')
# 獲取省份頻率分佈
province = mask_data['省'].value_counts()/mask_data['省'].value_counts().sum()
# 繪製省份頻率餅圖
province.plot(kind='pie', autopct='%.2f%%', figsize=(9, 9), fontsize=20, title='行业频率分布图', label='')
# Out:
# <AxesSubplot:title={'center':'行业频率分布图'}>

# %%
# 條形圖
province.plot(kind='bar', figsize=(13,6), title='省份頻率分佈條形圖')
# Out:
# <AxesSubplot:title={'center':'省份頻率分佈條形圖'}>

# %%
# 获取每月销售额总数
sales_income = mask_data.groupby('月份')['销售额'].sum()
sales_income
# Out:
# 月份
# 1       550370.0
# 2     29256800.0
# 3    343641650.0
# 4     27313800.0
# 5      6327520.0
# 6       666660.0
# Name: 销售额, dtype: float64

# %%
# 获取各月总订单量
order_number = mask_data.groupby('月份')['订单量'].sum()
order_number
# Out:
# 月份
# 1      13852.0
# 2     389319.0
# 3    1961480.0
# 4     546276.0
# 5     158188.0
# 6      22222.0
# Name: 订单量, dtype: float64

# %%
# 获取每月平均单价
month_price = mask_data.groupby('月份')['单价'].mean()
# 查看数据
month_price
# Out:
# 月份
# 1     38.878137
# 2     74.848017
# 3    175.518112
# 4     50.000000
# 5     40.000000
# 6     30.000000
# Name: 单价, dtype: float64

# %%
# 获取各月各省总订单量
month_order1 = mask_data.groupby(['省', '月份'])['订单量'].sum()
month_order2 = mask_data.groupby(['月份', '省'])['订单量'].sum()
# 查看数据
month_order1
month_order2
# Out:
# 月份  省
# 1   其他        452.0
#     广东       2628.0
#     江苏        263.0
#     河南        434.0
#     湖北       9055.0
#     湖南       1020.0
# 2   其他      10668.0
#     广东      77427.0
#     江苏       2530.0
#     河南      10058.0
#     湖北     259511.0
#     湖南      29125.0
# 3   其他      16871.0
#     广东     125618.0
#     江苏       4004.0
#     河南      18293.0
#     湖北    1731060.0
#     湖南      65634.0
# 4   其他       2713.0
#     广东      46708.0
#     江苏        106.0
#     河南       2917.0
#     湖北     476558.0
#     湖南      17274.0
# 5   其他       1250.0
#     广东      22364.0
#     江苏        118.0
#     河南       1239.0
#     湖北     126342.0
#     湖南       6875.0
# 6   其他        113.0
#     广东       4038.0
#     江苏        116.0
#     河南        107.0
#     湖北      17182.0
#     湖南        666.0
# Name: 订单量, dtype: float64

# %%
# 画出各月总销售额的折线图
sales_income.plot(kind='line', figsize=(7, 7), title='各月总销售额趋势图')
# Out:
# <AxesSubplot:title={'center':'各月总销售额趋势图'}, xlabel='月份'>

# %%
# 画出各月总订单量的折线图
order_number.plot(kind='line', figsize=(7, 7), title='各月总订单量趋势图')
# Out:
# <AxesSubplot:title={'center':'各月总订单量趋势图'}, xlabel='月份'>

# %%
# 画出各月平均单价的折线图
month_price.plot(kind='line', figsize=(7, 7), title='各月平均单价趋势图')
# Out:
# <AxesSubplot:title={'center':'各月平均单价趋势图'}, xlabel='月份'>

# %%
# 将month_order1转换为DataFrame，存储在month_order1_df中
month_order1_df = month_order1.unstack()
# 根据month_order1_df绘制多条折线图，标题为'各月各省总订单量趋势图'
month_order1_df.plot(kind='line', figsize=(7,7), title='各月各省总订单量趋势图')
# Out:
# <AxesSubplot:title={'center':'各月各省总订单量趋势图'}, xlabel='省'>

# %%
# 将month_order2转换为DataFrame，存储在month_order2_df中
month_order2_df = month_order2.unstack()
# 根据month_order2_df绘制多条折线图，标题为'各省各月总订单量趋势图'
month_order2_df.plot(kind='line', figsize=(7, 7), title='各省各月总订单量趋势图')
# Out:
# <AxesSubplot:title={'center':'各省各月总订单量趋势图'}, xlabel='月份'>

# %%
# Seaborn 库
import seaborn as sns

students_grade = pd.DataFrame({'李健': [80, 85, 89, 91, 88, 95],
                            '王聪': [95, 92, 90, 85, 75, 80],
                            '过凡': [90, 91, 92, 91, 90, 91]
                            }, index=['2月', '3月', '4月', '5月', '6月', '7月'])
# 绘制多条折线图
sns.lineplot(data=students_grade)
# Out:
# <AxesSubplot:>

# %%
# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))

# 设置 x/y 坐标值
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y = pd.Series([59, 70, 68, 56])

# 绘制折线图，并调整线条颜色为湖蓝色
plt.plot(x, y, color='dodgerblue')

# %%
# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))

# 设置 x/y 坐标值
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y = pd.Series([59, 70, 68, 56])

# 绘制柱状图，并调整颜色为深橘色
plt.bar(x, height=y, color='darkorange')

# 设置图表标题名及字体大小
plt.title('闪光科技2020年各季度研发费用分布图', fontsize=20)

# 设置坐标轴的刻度字体大小
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# 设置坐标轴的标题名及字体大小
plt.xlabel('季度', fontsize=15)
plt.ylabel('研发费用（百万元）', fontsize=15)

# 绘制折线图，并调整线条颜色为湖蓝色
plt.plot(x, y, color='dodgerblue')

# 设置图例为'研发费用变化'、'研发费用分布'
plt.legend(['研发费用变化', '研发费用分布'])

# %%
# zip函數
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y = pd.Series([59, 70, 68, 56])
for a, b in zip(x, y):
    print(a, b)
# Out:
# 第一季度 59
# 第二季度 70
# 第三季度 68
# 第四季度 56

# %%
# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))

# 设置 x/y 坐标值
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y = pd.Series([59, 70, 68, 56])

# 绘制柱状图，并调整颜色为深橘色
plt.bar(x, height=y, color='darkorange')

# 设置图表标题名及字体大小
plt.title('闪光科技2020年各季度研发费用分布图', fontsize=20)

# 设置坐标轴的刻度字体大小
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# 设置坐标轴的标题名及字体大小
plt.xlabel('季度', fontsize=15)
plt.ylabel('研发费用（百万元）', fontsize=15)

# 绘制折线图，并调整线条颜色为湖蓝色
plt.plot(x, y, color='dodgerblue')

# 设置图例为'研发费用变化'、'研发费用分布'
plt.legend(['研发费用变化', '研发费用分布'])

# 设置数据标签
for a, b in zip(x, y):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=12)

# %%
# 餅圖

# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))
# 设置扇形面积值
x = pd.Series([59, 70, 68, 56])
# 设置百分比小数的位数：保留百分比小数点后两位
autopct='%.2f%%'
# 设置百分比字体大小和颜色
textprops = {'fontsize': 12, 'color': 'black'}
# 设置饼图的“爆炸效果”：让扇形远离圆心
explode = [0.1, 0, 0, 0]
# 设置不同扇形的颜色
colors = ['cornflowerblue', 'salmon', 'yellowgreen', 'orange']
# 绘制饼图
plt.pie(x, autopct=autopct, textprops=textprops,
        explode=explode, colors=colors)
# 设置图表标题名及字体大小
plt.title('闪光科技2020年各季度研发费用占比饼图', fontsize=20)
# 设置图例
plt.legend(['第一季度', '第二季度', '第三季度', '第四季度'])

# %%
# 生成画布，并设置画布的大小为(6, 6)
plt.figure(figsize=(6,6))
# 设置 x/y 坐标值，x 坐标值为月份信息，y 坐标值为各月口罩总订单量
x = order_number.index
y = order_number.values
# 绘制折线图，并调整线条的样式
plt.plot(x,y,color='olivedrab')
# 设置图表标题名为'各月总订单量趋势图'，字体大小为 20
plt.title('各月总订单量趋势图', fontsize=20)
# 设置坐标轴的刻度字体大小为 12
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置 x、y 轴标题分别为'月份'、'各月总订单量（百万）'，字体大小均为 15
plt.xlabel('月份', fontsize=15)
plt.ylabel('各月总订单量（百万）',fontsize=15)
# Out:
# Text(0, 0.5, '各月总订单量（百万）')

# %%
# 提取各省各月订单量数据
month_order = mask_data.groupby(['月份', '省'])['订单量'].sum()
# 将多级索引的Series对象转换成DataFrame对象
month_order_df = month_order.unstack()
# 查看各省各月订单量数据
month_order_df
# Out:
# 省        其他        广东      江苏       河南         湖北       湖南
# 月份
# 1     452.0    2628.0   263.0    434.0     9055.0   1020.0
# 2   10668.0   77427.0  2530.0  10058.0   259511.0  29125.0
# 3   16871.0  125618.0  4004.0  18293.0  1731060.0  65634.0
# 4    2713.0   46708.0   106.0   2917.0   476558.0  17274.0
# 5    1250.0   22364.0   118.0   1239.0   126342.0   6875.0
# 6     113.0    4038.0   116.0    107.0    17182.0    666.0

# %%
# 生成画布，并设置画布的大小为(6, 6)
plt.figure(figsize=(6,6))
# 设置 x 坐标值为月份信息，y 坐标值为各个省份在各月口罩订单总量的信息
x = month_order_df.index
y = month_order_df.values
# 绘制折线图
plt.plot(x,y)
# 设置图表标题名为'各省各月口罩订单量变化折线图'，字体大小为 20
plt.title('各省各月口罩订单量变化折线图',fontsize=20)
# 设置坐标轴的刻度字体大小为 12
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置 x、y 轴标题分别为'月份'、'各省各月口罩订单量（百万）'，字体大小均为 15
plt.xlabel('月份', fontsize=15)
plt.xlabel('各省各月口罩订单量（百万）', fontsize=15)
# 添加图例，内容为：'其他', '广东', '江苏', '河南', '湖北', '湖南'
plt.legend(['其他','广东', '江苏', '河南', '湖北', '湖南'])

# %%
# 求得各月平均单价数据，并将其赋值给变量 mask_price
mask_price = mask_data.groupby('月份')['单价'].mean()
# 查看mask_price
mask_price
# Out:
# 月份
# 1     38.878137
# 2     74.848017
# 3    175.518112
# 4     50.000000
# 5     40.000000
# 6     30.000000
# Name: 单价, dtype: float64

# %%
# 生成画布，并设置画布的大小为(6, 6)
plt.figure(figsize=(6,6))
# 设置 x 坐标值为月份信息，y 坐标值为各月口罩平均单价
x = mask_price.index
y = mask_price.values
# 绘制柱状图，调整柱子的样式，并区分 1 月份和 6 月份颜色
plt.bar(x, height=y, color=['r', 'g', 'g', 'g', 'g', 'b'])
# 设置图表标题名为'各月平均单价分布图'，字体大小为 20
plt.title('各月平均单价分布图', fontsize=20)
# 坐标轴的刻度字体大小为 12
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置 x、y 轴标题分别为'月份'、'各月平均单价（元）'，字体大小均为 15
plt.xlabel('月份',fontsize=15)
plt.ylabel('各月平均单价（元）', fontsize=15)
# 为柱子添加每一个数据标签，数值是 y 坐标值
for a, b in zip(x,y):
    plt.text(a,b,'%.0f'%b, ha='center', va='bottom', fontsize=12)

# %%
# 设置字体样式字典
font1 = {'family': 'KaiTi',
        'color':  'black',
        'weight': 'bold',
        'size': 20,
        }
font2 = {'family': 'KaiTi',
        'color':  'red',
        'weight': 'normal',
        'size': 12,
        }
# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))
# 设置 x/y 的坐标值
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y = pd.Series([160, 200, 180, 165])
# 绘制柱状图
plt.bar(x, height=y, color='darkorange', alpha=0.6)
# 设置图表标题名及字体样式
plt.title('闪光科技2020年各季度研发费用分布图', fontdict=font1)
# 设置数据标签及字体样式
for a, b in zip(x, y):
    plt.text(a, b, b, ha='center', va='bottom', fontdict=font2)

# %%
# 折綫寬度

# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))
# 设置坐标值
x = pd.Series(['第一季度', '第二季度', '第三季度', '第四季度'])
y1 = pd.Series([160, 200, 180, 165])
y2 = pd.Series([140, 160, 170, 160])
plt.plot(x, y1)
# 设置数据标记点的形状为圆：'o'；大小为 10；填充颜色为白色：'w'
plt.plot(x, y2, linewidth=3, marker='o',
        markersize=10, markerfacecolor='w')
# 设置标题名及字体大小
plt.title('闪光科技2019-2020年各季度营业收入趋势图', fontsize=20)
# 设置坐标轴的标题名及字体大小
plt.xlabel('季度', fontsize=15)
plt.ylabel('营业收入（百万元）', fontsize=15)
# 设置坐标轴的刻度字体大小
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置图例
plt.legend(['2019年', '2020年'])

# %%
# 柱狀圖透明度，顔色，寬度

# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))
# 设置 x/y 的坐标值
x = pd.Series(['2020Q1', '2020Q2', '2020Q3', '2020Q4'])
y = pd.Series([59, 70, 68, 56])
# 绘制柱状图，设置柱子的宽度为 0.6
plt.bar(x, height=y, color=['g', 'g', 'r', 'g'], alpha=0.6, width=0.1)
# 设置图表标题名及字体大小
plt.title('闪光科技2020年各季度研发费用分布图', fontsize=20)
# 设置坐标轴的刻度字体大小
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置坐标轴的标题名及字体大小
plt.xlabel("季度", fontsize=15)
plt.ylabel("研发费用（百万元）", fontsize=15)
# Out:
# Text(0, 0.5, '研发费用（百万元）')

# %%
# 保存畫布

# 生成画布，并设置画布的大小
plt.figure(figsize=(6, 6))
# 设置 x/y 的坐标值
x = pd.Series(['2020Q1', '2020Q2', '2020Q3', '2020Q4'])
y = pd.Series([59, 70, 68, 56])
# 绘制柱状图，设置柱子的宽度为 0.6
plt.bar(x, height=y, color=['g', 'g', 'r', 'g'], alpha=0.6, width=0.6)
# 设置图表标题名及字体大小
plt.title('闪光科技2020年各季度研发费用分布图', fontsize=20)
# 设置坐标轴的刻度字体大小
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# 设置坐标轴的标题名及字体大小
plt.xlabel("季度", fontsize=15)
plt.ylabel("研发费用（百万元）", fontsize=15)
# 保存画布，并设置保存路径
plt.savefig('闪光科技2020年各季度研发费用分布图.png') # dpi, format, transparent

# %%
# Series 对象排序
y = y.sort_values(ascending=False)
plt.figure(figsize=(6, 6))
plt.bar(x, height=y, color=['g', 'g', 'r', 'g'], alpha=0.6, width=0.6)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
plt.xlabel("季度", fontsize=15)
plt.ylabel("研发费用（百万元）", fontsize=15)
plt.savefig('闪光科技2020年各季度研发费用分布图.png') # dpi, format, transparent

# %%
# 嵌套列表創建DF

# 设置列表
students_info = [['小蓝', '语文', '79'],
        ['小邱', '数学', '83'],
        ['小李', '英语', '92']]

# 使用列表创建 DataFrame 对象，同时设置列名
students_df = pd.DataFrame(students_info, columns=['姓名', '科目', '分数'])
students_df
# Out:
#    姓名  科目  分数
# 0  小蓝  语文  79
# 1  小邱  数学  83
# 2  小李  英语  92

# %%
# 排序+重置索引
# 创建一个 DataFrame 对象的数据
humans_df = pd.DataFrame({'姓名': ['小猿', '小马', '小鱼', '小猫', '小龙'], '身高': ['165', '170', '160', '172', '178'], '体重': [56, 45, 60, 40, 70]})

# 依照【身高】列的数据进行升序排序
reset_humans = humans_df.sort_values(by='身高')
# 重置索引，且不保留原索引
reset_humans.reset_index(drop=True)
# Out:
#    姓名   身高  体重
# 0  小鱼  160  60
# 1  小猿  165  56
# 2  小马  170  45
# 3  小猫  172  40
# 4  小龙  178  70

# %%
# 數據四捨五入

# 创建一个 DataFrame 对象的数据
humans_df = pd.DataFrame({'姓名': ['小猿', '小马', '小鱼', '小猫', '小龙'], '身高': ['165', '170', '160', '172', '178'], '体重': [56.25, 45.63, 60.72, 40.34, 70.5]})
# 保留【体重】列的数据到一位小数
humans_df['体重'] = round(humans_df['体重'], 1)
humans_df
# Out:
#    姓名   身高    体重
# 0  小猿  165  56.2
# 1  小马  170  45.6
# 2  小鱼  160  60.7
# 3  小猫  172  40.3
# 4  小龙  178  70.5

# %%
# agg 函數

# 创建一个 DataFrame 对象的数据
foods_df = pd.DataFrame({'食品名': ['肚脐饼', '水晶饺', '擂茶', '肚脐饼', '擂茶'], '单价': [2, 10, 12, 4, 20], '数量': [20, '-', 35, 37, '-'], '城市': ['潮州', '汕尾', '梅州', '深圳', '深圳']})
# 定义函数，以替换【数量】列的“-”为 0
def iszero(data):
    if data == '-':
        data = 0
    return int(data)
# 使用 agg() 方法对【数量】列的内容进行替换
foods_df['数量']=foods_df['数量'].agg(iszero)
# 同时计算【单价】列的最小值和【数量】列的最大值
foods_df.groupby('食品名').agg({'单价':'min','数量':'max'})
# Out:
#      单价  数量
# 食品名
# 擂茶   12  35
# 水晶饺  10   0
# 肚脐饼   2  37

# %%
# apriori

# 导入 apyori 模块下的 apriori() 函数
from apyori import apriori
# 创建4条快餐交易数据
orders = [['薯条', '可乐'], ['薯条', '可乐', '奶茶'], ['汉堡', '薯条', '可乐'], ['汉堡', '可乐']]
# 创建变量 results，调用 apriori() 函数，传入 orders ，设置最小支持度为 0.2，最小置信度为 0.7
results = apriori(orders, min_support=0.2, min_confidence=0.7)
# 查看变量 results
results
# Out:
# <generator object apriori at 0x0000025E66E17F48>

# %%
for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'可乐'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'薯条'}), support=0.75, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'薯条'}), confidence=0.75, lift=1.0)])
# RelationRecord(items=frozenset({'可乐', '奶茶'}), support=0.25, ordered_statistics=[OrderedStatistic(items_base=frozenset({'奶茶'}), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'可乐', '汉堡'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset({'汉堡'}), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'可乐', '薯条'}), support=0.75, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'可乐', '薯条'}), confidence=0.75, lift=1.0), OrderedStatistic(items_base=frozenset({'可乐'}), items_add=frozenset({'薯条'}), confidence=0.75, lift=1.0), OrderedStatistic(items_base=frozenset({'薯条'}), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'薯条', '奶茶'}), support=0.25, ordered_statistics=[OrderedStatistic(items_base=frozenset({'奶茶'}), items_add=frozenset({'薯条'}), confidence=1.0, lift=1.3333333333333333)])
# RelationRecord(items=frozenset({'可乐', '薯条', '奶茶'}), support=0.25, ordered_statistics=[OrderedStatistic(items_base=frozenset({'奶茶'}), items_add=frozenset({'可乐', '薯条'}), confidence=1.0, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'可乐', '奶茶'}), items_add=frozenset({'薯条'}), confidence=1.0, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'薯条', '奶茶'}), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'可乐', '薯条', '汉堡'}), support=0.25, ordered_statistics=[OrderedStatistic(items_base=frozenset({'薯条', '汉堡'}), items_add=frozenset({'可乐'}), confidence=1.0, lift=1.0)])

# %%
# 调用 apriori() 函数
results = apriori(orders, min_support=0.2, min_confidence=0.7)
# 遍历结果数据
for result in results:
    # 获取支持度,并保留3位小数
    support = round(result.support, 3)

    # 遍历ordered_statistics对象
    for rule in result.ordered_statistics:
        # 获取前件和后件并转成列表
        head_set = list(rule.items_base)
        tail_set = list(rule.items_add)

        # 跳过前件为空的数据
        if head_set == []:
                continue

        # 将前件、后件拼接成关联规则的形式
        related_catogory = str(head_set) + '→' + str(tail_set)

        # 提取置信度，并保留3位小数
        confidence = round(rule.confidence, 3)
        # 提取提升度，并保留3位小数
        lift = round(rule.lift, 3)

        # 查看强关联规则，支持度，置信度，提升度
        print(related_catogory, support, confidence, lift)
# Out:
# ['奶茶']→['可乐'] 0.25 1.0 1.0
# ['汉堡']→['可乐'] 0.5 1.0 1.0
# ['可乐']→['薯条'] 0.75 0.75 1.0
# ['薯条']→['可乐'] 0.75 1.0 1.0
# ['奶茶']→['薯条'] 0.25 1.0 1.333
# ['奶茶']→['可乐', '薯条'] 0.25 1.0 1.333
# ['可乐', '奶茶']→['薯条'] 0.25 1.0 1.333
# ['薯条', '奶茶']→['可乐'] 0.25 1.0 1.0
# ['薯条', '汉堡']→['可乐'] 0.25 1.0 1.0

# %%
# 案例：公衆號關聯度
user_data = pd.read_csv('公众号用户访问数据.csv', encoding='utf-8')
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   用户编号    199 non-null    int64
#  1   文章类别    199 non-null    object
#  2   阅读数     199 non-null    int64
#  3   看一看     199 non-null    int64
#  4   点赞      199 non-null    int64
#  5   赞赏      199 non-null    int64
#  6   被转载     199 non-null    int64
#  7   访问日期    199 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 12.6+ KB

# %%
# 提取列数据（'用户编号', '文章类别', '访问日期'），并进行赋值
analysis_data = user_data[['用户编号','文章类别','访问日期']]
# 查看提取的数据
analysis_data
# Out:
#      用户编号        文章类别       访问日期
# 0       1        数据分析  2020/9/21
# 1       2        数据分析  2020/9/17
# 2       3        数据分析   2020/9/2
# 3       4        数据分析  2020/9/24
# 4       5        数据分析   2020/9/8
# ..    ...         ...        ...
# 194    98      pandas  2020/9/20
# 195    98      pandas  2020/9/20
# 196    99        数据分析  2020/9/23
# 197    99      pandas  2020/9/23
# 198    99  matplotlib  2020/9/23
#
# [199 rows x 3 columns]

# %%
# 查看提取数据后的重复数据
analysis_data[analysis_data.duplicated()]
# 去除重复数据
analysis_data = analysis_data.drop_duplicates()

# %%
# 定义“格式转换”函数
def conversion_data(category):

    # 判断文章类别是否已经转成了列表格式
    if str(category)[0] == '[':
        # 直接返回文章类别
        return category
    # 返回转成列表格式后的文章类别
    return [category]


# 获取'文章类别'列，调用 agg() 方法
analysis_data['文章类别'] = analysis_data['文章类别'].agg(conversion_data)
# 查看处理后的数据
analysis_data
# Out:
# ipykernel_launcher:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      用户编号          文章类别       访问日期
# 0       1        [数据分析]  2020/9/21
# 1       2        [数据分析]  2020/9/17
# 2       3        [数据分析]   2020/9/2
# 3       4        [数据分析]  2020/9/24
# 4       5        [数据分析]   2020/9/8
# ..    ...           ...        ...
# 193    98        [数据分析]  2020/9/20
# 194    98      [pandas]  2020/9/20
# 196    99        [数据分析]  2020/9/23
# 197    99      [pandas]  2020/9/23
# 198    99  [matplotlib]  2020/9/23
#
# [192 rows x 3 columns]

# %%
# 根据'访问日期'和'用户编号'进行分组，并聚合'文章类别'列
adjusted_data = analysis_data.groupby(['访问日期', '用户编号']).sum()
# 查看整理后的数据
adjusted_data
# Out:
#                               文章类别
# 访问日期      用户编号
# 2020/9/1  20                [数据分析]
#           44        [Python, 数据分析]
#           60          [Python, 爬虫]
# 2020/9/10 14                [数据分析]
#           47            [爬虫, 数据分析]
# ...                            ...
# 2020/9/8  28              [Python]
#           64    [Python, 爬虫, 数据分析]
#           79         [Python, sql]
# 2020/9/9  46              [Python]
#           81         [Python, sql]
#
# [99 rows x 1 columns]

# %%
# 提取'文章类别'列数据，调用 apriori() 函数，设置最小支持度为 0.1 ，使用默认最小置信度
results = apriori(adjusted_data['文章类别'], min_support=0.1)

# 遍历结果数据
for result in results:
    # 获取支持度,并保留 3 位小数
    support = round(result.support, 3)

    # 遍历ordered_statistics对象
    for rule in result.ordered_statistics:
        # 获取前件和后件并转成列表
        head_set = list(rule.items_base)
        tail_set = list(rule.items_add)

        # 跳过前件为空的数据
        if head_set == []:
                continue

        # 将前件、后件拼接成关联规则的形式
        related_catogory = str(head_set) + '→' + str(tail_set)

        # 提取置信度，并保留 3 位小数
        confidence = round(rule.confidence, 3)
        # 提取提升度，并保留 3 位小数
        lift = round(rule.lift, 3)

        # 查看强关联规则，支持度，置信度，提升度
        print(related_catogory, support, confidence, lift)
# Out:
# ['Python']→['sql'] 0.101 0.233 2.302
# ['sql']→['Python'] 0.101 1.0 2.302
# ['Python']→['数据分析'] 0.323 0.744 0.91
# ['数据分析']→['Python'] 0.323 0.395 0.91
# ['Python']→['爬虫'] 0.141 0.326 1.04
# ['爬虫']→['Python'] 0.141 0.452 1.04
# ['pandas']→['数据分析'] 0.182 1.0 1.222
# ['数据分析']→['pandas'] 0.182 0.222 1.222
# ['数据分析']→['爬虫'] 0.192 0.235 0.749
# ['爬虫']→['数据分析'] 0.192 0.613 0.749

# %%
# 提取置信度
# 设置空的置信度列表
confidences_list = []

# 调用 apriori() 函数，生成关联规则
results = apriori(adjusted_data['文章类别'], min_support=0.1)

# 遍历统计列表中的关联规则，提取置信度
for result in results:
    for rule in result.ordered_statistics:

        # 获取前件并转成列表
        head_set = list(rule.items_base)

        # 跳过前件为空的数据
        if head_set == []:
                continue

        # 提取置信度，并保留 3 位小数
        confidence = round(rule.confidence, 3)

        # 将置信度写入置信度列表
        confidences_list.append(confidence)
# 查看置信度列表
confidences_list
# Out:
# [0.233, 1.0, 0.744, 0.395, 0.326, 0.452, 1.0, 0.222, 0.235, 0.613]

# %%
# 提取关联规则的置信度，生成 Series 数据
s = pd.Series(confidences_list)
# 查看置信度的描述性统计信息
s.describe()
# Out:
# count    10.000000
# mean      0.522000
# std       0.303657
# min       0.222000
# 25%       0.257750
# 50%       0.423500
# 75%       0.711250
# max       1.000000
# dtype: float64

# %%
# 对关联规则的置信度的 Series 数据进行排序
s.sort_values()
# Out:
# 7    0.222
# 0    0.233
# 8    0.235
# 4    0.326
# 3    0.395
# 5    0.452
# 9    0.613
# 2    0.744
# 1    1.000
# 6    1.000
# dtype: float64

# %%
# 提取'文章类别'列数据，调用 apriori() 函数，设置最小支持度为 0.1 ，设置最小置信度 0.3
results = apriori(adjusted_data['文章类别'], min_support=0.1, min_confidence=0.3)

# 创建空列表，存储关联规则列表，形成嵌套列表
extract_result = []

for result in results:
    # 获取支持度,并保留 3 位小数
    support = round(result.support, 3)

    # 遍历ordered_statistics对象
    for rule in result.ordered_statistics:
        # 获取前件和后件并转成列表
        head_set = list(rule.items_base)
        tail_set = list(rule.items_add)

        # 跳过前件为空的数据
        if head_set == []:
                continue

        # 将前件、后件拼接成关联规则的形式
        related_catogory = str(head_set) + '→' + str(tail_set)

        # 提取置信度，并保留 3 位小数
        confidence = round(rule.confidence, 3)
        # 提取提升度，并保留 3 位小数
        lift = round(rule.lift, 3)

        # 查看强关联规则，支持度，置信度，提升度
        print(related_catogory, support, confidence, lift)
        
        # 将提取的数据保存到提取列表中
        extract_result.append(
            [related_catogory, support, confidence, lift])

# 将数据转成 DataFrame 的形式
rules_data = pd.DataFrame(extract_result, columns=['关联规则', '支持度', '置信度', '提升度'])

# 将数据按照“支持度”排序
sorted_by_support = rules_data.sort_values(by='支持度')

# 查看排序后的数据
sorted_by_support
# Out:
# ['sql']→['Python'] 0.101 1.0 2.302
# ['Python']→['数据分析'] 0.323 0.744 0.91
# ['数据分析']→['Python'] 0.323 0.395 0.91
# ['Python']→['爬虫'] 0.141 0.326 1.04
# ['爬虫']→['Python'] 0.141 0.452 1.04
# ['pandas']→['数据分析'] 0.182 1.0 1.222
# ['爬虫']→['数据分析'] 0.192 0.613 0.749
#                   关联规则    支持度    置信度    提升度
# 0   ['sql']→['Python']  0.101  1.000  2.302
# 3    ['Python']→['爬虫']  0.141  0.326  1.040
# 4    ['爬虫']→['Python']  0.141  0.452  1.040
# 5  ['pandas']→['数据分析']  0.182  1.000  1.222
# 6      ['爬虫']→['数据分析']  0.192  0.613  0.749
# 1  ['Python']→['数据分析']  0.323  0.744  0.910
# 2  ['数据分析']→['Python']  0.323  0.395  0.910

# %%
# 提取出提升度大于 1 的数据，并重置数据的索引
promoted_rules = sorted_by_support[sorted_by_support['提升度'] > 1].reset_index(drop=True)
promoted_rules
# Out:
#                   关联规则    支持度    置信度    提升度
# 0   ['sql']→['Python']  0.101  1.000  2.302
# 1    ['Python']→['爬虫']  0.141  0.326  1.040
# 2    ['爬虫']→['Python']  0.141  0.452  1.040
# 3  ['pandas']→['数据分析']  0.182  1.000  1.222

# %%
# 提取出提升度小于 1 的数据，并重置数据的索引
sorted_by_lift = rules_data.sort_values(by='提升度')
impair_rules = sorted_by_lift[sorted_by_lift['提升度']<1].reset_index(drop=True)
impair_rules
# Out:
#                   关联规则    支持度    置信度    提升度
# 0      ['爬虫']→['数据分析']  0.192  0.613  0.749
# 1  ['Python']→['数据分析']  0.323  0.744  0.910
# 2  ['数据分析']→['Python']  0.323  0.395  0.910

# %%
import warnings

# 关闭警告显示
warnings.filterwarnings('ignore')

# 设置画布尺寸
plt.figure(figsize=(10, 8))

# 设置横纵坐标以及柱子的宽度
width = 0.2

# 画出柱状图
plt.bar(promoted_rules.index-width/2, promoted_rules['支持度'], width=width)
plt.bar(promoted_rules.index+width/2, promoted_rules['置信度'], width=width)

# 设置图例
plt.legend(['支持度', '置信度'], fontsize=20)
# 设置标题
plt.title('促进关系的关联规则的支持度、置信度', fontsize=25)
# 设置刻度名称
plt.xticks(promoted_rules.index, promoted_rules['关联规则'], fontsize=15)
# 设置坐标轴标签
plt.xlabel('关联规则', fontsize=20)
plt.ylabel('数值', fontsize=20)
# Out:
# Text(0, 0.5, '数值')

# %%
# 功能：绘制提升度小于 1 的强关联规则柱状图
# 设置画布尺寸
plt.figure(figsize=(10, 8))

# 设置横纵坐标以及柱子的宽度
width = 0.2

# 画出柱状图
plt.bar(impair_rules.index-width/2, impair_rules['支持度'], width=width)
plt.bar(impair_rules.index+width/2, impair_rules['置信度'], width=width)

# 设置图例
plt.legend(['支持度', '置信度'], fontsize=20)
# 设置标题
plt.title('限制关系的关联规则的支持度、置信度', fontsize=25)
# 设置刻度名称
plt.xticks(impair_rules.index, impair_rules['关联规则'], fontsize=15)
# 设置坐标轴标签
plt.xlabel('关联规则', fontsize=20)
plt.ylabel('数值', fontsize=20)
# Out:
# Text(0, 0.5, '数值')

# %%
rules_data
# Out:
#                   关联规则    支持度    置信度    提升度
# 0   ['sql']→['Python']  0.101  1.000  2.302
# 1  ['Python']→['数据分析']  0.323  0.744  0.910
# 2  ['数据分析']→['Python']  0.323  0.395  0.910
# 3    ['Python']→['爬虫']  0.141  0.326  1.040
# 4    ['爬虫']→['Python']  0.141  0.452  1.040
# 5  ['pandas']→['数据分析']  0.182  1.000  1.222
# 6      ['爬虫']→['数据分析']  0.192  0.613  0.749

# %%
# 设置画布尺寸
plt.figure(figsize=(20, 8))

# 画出柱状图
# 设置横纵坐标以及柱子的宽度
width = 0.2

# 画出柱状图
plt.bar(rules_data.index, rules_data['提升度'], width=width)

# 设置图例
plt.legend(['提升度'], fontsize=20)
# 设置标题
plt.title('強关联规则的提升度', fontsize=25)
# 设置刻度名称
plt.xticks(rules_data.index, rules_data['关联规则'], fontsize=15, rotation=90) # 刻度間隔，刻度名稱
# 设置坐标轴标签
plt.xlabel('关联规则', fontsize=20)
plt.ylabel('数值', fontsize=20)

# 设置数据标签
for a, b in zip(rules_data.index, rules_data['提升度']):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=12)

# %%
# ignore_index 参数

# 部分唐朝诗人数据
df_1 = pd.DataFrame({'诗人': ['白居易', '李白', '杜甫', '王勃', '王维'],
                    '称号': ['诗魔', '诗仙', '诗圣', '诗杰', '诗佛'],
                    '年龄': [74, 61, 58, 26, 60],
                    '诗歌大致数量': [3000, 900, 1500, 80, 400]})

# 按诗人的诗歌大致数量从高到低进行排序        
df_1.sort_values(by='诗歌大致数量', ascending=False)

# 部分唐朝诗人数据
df_2 = pd.DataFrame({'诗人': ['白居易', '李白', '杜甫', '王勃', '王维'],
                    '称号': ['诗魔', '诗仙', '诗圣', '诗杰', '诗佛'],
                    '年龄': [74, 61, 58, 26, 60],
                    '诗歌大致数量': [3000, 900, 1500, 80, 400]})

# 按诗人的诗歌大致数量从高到低进行排序并重置行索引
df_2 = df_2.sort_values(by='诗歌大致数量', ascending=False).reset_index(drop=True)

# 部分唐朝诗人数据
df_3 = pd.DataFrame({'诗人': ['白居易', '李白', '杜甫', '王勃', '王维'],
                    '称号': ['诗魔', '诗仙', '诗圣', '诗杰', '诗佛'],
                    '年龄': [74, 61, 58, 26, 60],
                    '诗歌大致数量': [3000, 900, 1500, 80, 400]})

# 按诗人的诗歌大致数量从高到低进行排序并重置行索引
df_3 = df_3.sort_values(by='诗歌大致数量', ascending=False, ignore_index=True)

# 带有重复行的部分唐朝诗人数据
df_5 = pd.DataFrame({'诗人': ['白居易', '李白', '杜甫', '王勃', '王勃', '王维'],
                    '称号': ['诗魔', '诗仙', '诗圣', '诗杰', '诗杰', '诗佛'],
                    '年龄': [74, 61, 58, 26, 26, 60],
                    '诗歌大致数量': [3000, 900, 1500, 80, 80, 400]})

# 使用 drop_duplicates() 方法删除重复行并用 ignore_index 参数重置行索引
df_5 = df_5.drop_duplicates(ignore_index=True)

# 查看数据
df_5
# Out:
#     诗人  称号  年龄  诗歌大致数量
# 0  白居易  诗魔  74    3000
# 1   李白  诗仙  61     900
# 2   杜甫  诗圣  58    1500
# 3   王勃  诗杰  26      80
# 4   王维  诗佛  60     400

# %%
# RFM 電商客戶價值細分

# read_excel() 函数
# 打开【成绩单.xlsx】工作簿，并获取【1 班】工作表的数据
data_1 = pd.read_excel('成绩单.xlsx', sheet_name='1 班')
data_1
# Out:
#    学号 性别  年龄   总分
# 0   1  男  15  290
# 1   2  女  16  205
# 2   3  男  17  240
# 3   4  女  15  247
# 4   5  男  16  288

# %%
# to_excel() 函數
# 创建一个 DataFrame 对象的数据
data_2 = pd.DataFrame({'学号':[1, 2, 3], '性别':['男', '男', '女'], '年龄':['17', '17', '16'], '总分':['285', '273', '240']})
# 将数据写入到【新成绩单.xlsx】工作簿中的【2 班】工作表
data_2.to_excel('新成绩单.xlsx', sheet_name='2 班', index=False)

# %%
# 數據類型轉化
# 创建一个 DataFrame 对象的数据
data_5 = pd.DataFrame({'姓名':['林某某', '许放羊', '王鱼'], '语文': [87, 82, 67], '数学':[73, 85, 90], '英语':['89', '95', '95']})
# 计算每个人三门科目的总分
data_5['总分'] = data_5['语文'] + data_5['数学'] + data_5['英语'].astype(int)
data_5
# Out:
#     姓名  语文  数学  英语   总分
# 0  林某某  87  73  89  249
# 1  许放羊  82  85  95  262
# 2   王鱼  67  90  95  252

# %%
# 数据的批量替换
# 创建一个 DataFrame 对象的数据
data_7 = pd.DataFrame({'性别':['难', '女', '难', '女', '女'],
                       '城市':['.', '潮州市', '山头市', '汕尾市', '山头市'],
                       '年龄':[25, 26, 24, 25, 26],
                       '爱好':['蓝球', '跑步', '跳舞', '逛街', '读书']})                       
# 定义字典 fix_typo
fix_typo = {'山头市':'汕头市', '蓝球':'篮球'}
# 对【城市】、【爱好】列的错字进行修改
data_7 = data_7.replace(fix_typo)
data_7
# Out:
#   性别   城市  年龄  爱好
# 0  难    .  25  篮球
# 1  女  潮州市  26  跑步
# 2  难  汕头市  24  跳舞
# 3  女  汕尾市  25  逛街
# 4  女  汕头市  26  读书

# %%
# 重置 data_7 的数据
data_7 = pd.DataFrame({'性别':['难', '女', '难', '女', '女'],
                       '城市':['.', '潮州市', '山头市', '汕尾市', '山头市'],
                       '年龄':[25, 26, 24, 25, 26],
                       '爱好':['蓝球', '跑步', '跳舞', '逛街', '读书']})
# 定义字典 fix_typo
fix_typo = {'山头市':'汕头市', '蓝球':'篮球'}
# 对【城市】列的错字进行修改
data_7['城市'] = data_7['城市'].replace(fix_typo)
# 将【性别】列的“难”替换为“男”，【城市】列的“.”替换为“未知”
data_7.replace({'难':'男', '.':'未知'})
# Out:
#   性别   城市  年龄  爱好
# 0  男   未知  25  蓝球
# 1  女  潮州市  26  跑步
# 2  男  汕头市  24  跳舞
# 3  女  汕尾市  25  逛街
# 4  女  汕头市  26  读书

# %%
data_7
# Out:
#   性别   城市  年龄  爱好
# 0  难    .  25  蓝球
# 1  女  潮州市  26  跑步
# 2  难  汕头市  24  跳舞
# 3  女  汕尾市  25  逛街
# 4  女  汕头市  26  读书

# %%
# 导入客户数据
customer_info = pd.read_excel('客户数据.xlsx')
# 查看数据的描述性统计值
customer_info.describe()
# Out:
#               客户 ID       消费频次  最近一次消费时间间隔（天）        消费总金额
# count     10.000000  10.000000      10.000000    10.000000
# mean   41293.400000   3.700000       6.100000   434.000000
# std    30904.971737   2.002776       4.067486   625.765309
# min    10932.000000   1.000000       2.000000    20.000000
# 25%    18926.000000   2.000000       3.250000    77.500000
# 50%    26136.500000   3.500000       5.000000   150.000000
# 75%    66951.250000   5.000000       7.750000   450.000000
# max    98821.000000   7.000000      15.000000  2000.000000

# %%
# 定义函数：按照中位数划分 R 值
def calculate_r(s):
    if s <= 3.5:
        return '低'
    else:
        return '高'


# 对 R 值进行评分
customer_info['R值高低'] = customer_info['消费频次'].agg(calculate_r)
# 查看添加评分后的客户数据
customer_info
# Out:
#    客户 ID  消费频次  最近一次消费时间间隔（天）  消费总金额 R值高低
# 0  10932     5              5   1000    高
# 1  18823     2             10    200    低
# 2  19235     1             15     20    低
# 3  22889     7              3   2000    高
# 4  43288     6              2    500    高
# 5  29384     3              5    100    低
# 6  76429     4              2    300    高
# 7  74839     2              8     50    低
# 8  98821     2              4     70    低
# 9  18294     5              7    100    高

# %%
# 定义函数：按照中位数划分 F 值
def calculate_f(s):
    if s <= 5:
        return '低'
    else:
        return '高'


# 对 F 值进行评分
customer_info['F值高低'] = customer_info['最近一次消费时间间隔（天）'].agg(calculate_f)

# 定义函数：按照中位数划分 M 值
def calculate_m(s):
    if s <= 150:
        return '低'
    else:
        return '高'



# 对 M 值进行评分
customer_info['M值高低'] = customer_info['消费总金额'].agg(calculate_m)

# 查看添加评分后的客户数据
customer_info
# Out:
#    客户 ID  消费频次  最近一次消费时间间隔（天）  消费总金额 R值高低 F值高低 M值高低
# 0  10932     5              5   1000    高    低    高
# 1  18823     2             10    200    低    高    高
# 2  19235     1             15     20    低    高    低
# 3  22889     7              3   2000    高    低    高
# 4  43288     6              2    500    高    低    高
# 5  29384     3              5    100    低    低    低
# 6  76429     4              2    300    高    低    高
# 7  74839     2              8     50    低    高    低
# 8  98821     2              4     70    低    低    低
# 9  18294     5              7    100    高    高    低

# %%
data = pd.read_excel('商品销售数据.xlsx')
data.head(10)
# Out:
#       订单号      邮编            商品描述  数量              发货日期    价格    用户 ID  国家
# 0  536365  85123A           清蒸臭豆腐   6  2010/01/12 08:26  2.55  17850.0  英国
# 1  536365   71053  self-raising面粉   6  2010/01/12 08:26  3.39  17850.0  英国
# 2  536365  84406B             佛跳墙   8  2010/01/12 08:26  2.75  17850.0  英国
# 3  536365  84029G            五香熏蛋   6  2010/01/12 08:26  3.39  17850.0  英国
# 4  536365  84029E            鸭胸脯肉   6  2010/01/12 08:26  3.39  17850.0  英国
# 5  536365   22752              羊血   2  2010/01/12 08:26  7.65  17850.0  英国
# 6  536365   21730        奥来克桂花莲藕粉   6  2010/01/12 08:26  4.25  17850.0  英国
# 7  536366   22633            腌韭菜花   6  2010/01/12 08:28  1.85  17850.0  英国
# 8  536366   22632             燔鱼片   6  2010/01/12 08:28  1.85  17850.0  英国
# 9  536367   84879             酱莴笋  32  2010/01/12 08:34  1.69  13047.0  英国

# %%
# 數據清洗
# 将读取到的工作簿数据，进行缺失值、重复值和异常值的清洗
data=data.dropna()
data=data.drop_duplicates()
data=data[data['数量'] >= 0]

# %%
# 计算“总金额”
data['总金额'] = data['数量'] * data['价格']
data.head(10)
# Out:
#       订单号      邮编            商品描述  数量              发货日期    价格    用户 ID  国家  \
# 0  536365  85123A           清蒸臭豆腐   6  2010/01/12 08:26  2.55  17850.0  英国
# 1  536365   71053  self-raising面粉   6  2010/01/12 08:26  3.39  17850.0  英国
# 2  536365  84406B             佛跳墙   8  2010/01/12 08:26  2.75  17850.0  英国
# 3  536365  84029G            五香熏蛋   6  2010/01/12 08:26  3.39  17850.0  英国
# 4  536365  84029E            鸭胸脯肉   6  2010/01/12 08:26  3.39  17850.0  英国
# 5  536365   22752              羊血   2  2010/01/12 08:26  7.65  17850.0  英国
# 6  536365   21730        奥来克桂花莲藕粉   6  2010/01/12 08:26  4.25  17850.0  英国
# 7  536366   22633            腌韭菜花   6  2010/01/12 08:28  1.85  17850.0  英国
# 8  536366   22632             燔鱼片   6  2010/01/12 08:28  1.85  17850.0  英国
# 9  536367   84879             酱莴笋  32  2010/01/12 08:34  1.69  13047.0  英国
#
#      总金额
# 0  15.30
# 1  20.34
# 2  22.00
# 3  20.34
# 4  20.34
# 5  15.30
# 6  25.50
# 7  11.10
# 8  11.10
# 9  54.08

# %%
# 按【订单号】和【用户 ID】分组后，获取【发货日期】列的最大值和【总金额】列的总和
grouped_data = data.groupby(['订单号', '用户 ID'], as_index=False).agg({'发货日期': 'max', '总金额': 'sum'})
grouped_data.head(10)
# Out:
#       订单号    用户 ID                发货日期      总金额
# 0  581587  12680.0 2011-09-12 12:50:00   249.45
# 1  536365  17850.0 2010-01-12 08:26:00   139.12
# 2  536366  17850.0 2010-01-12 08:28:00    22.20
# 3  536367  13047.0 2010-01-12 08:34:00   278.73
# 4  536374  15100.0 2010-01-12 09:09:00   350.40
# 5  536376  15291.0 2010-01-12 09:32:00   328.80
# 6  536378  14688.0 2010-01-12 09:37:00   444.98
# 7  536385  17420.0 2010-01-12 09:56:00   130.85
# 8  536386  16029.0 2010-01-12 09:57:00   508.20
# 9  536387  16029.0 2010-01-12 09:58:00  3193.92

# %%
# 计算时间间隔
today = '2012-01-01 00:00:00'
grouped_data['时间间隔'] = (pd.to_datetime(today) - pd.to_datetime(grouped_data['发货日期'])).dt.days
grouped_data
# Out:
#          订单号    用户 ID                发货日期     总金额  时间间隔
# 0     581587  12680.0 2011-09-12 12:50:00  249.45   110
# 1     536365  17850.0 2010-01-12 08:26:00  139.12   718
# 2     536366  17850.0 2010-01-12 08:28:00   22.20   718
# 3     536367  13047.0 2010-01-12 08:34:00  278.73   718
# 4     536374  15100.0 2010-01-12 09:09:00  350.40   718
# ...      ...      ...                 ...     ...   ...
# 4574  581572  16705.0 2011-09-12 12:08:00  250.52   110
# 4575  581579  17581.0 2011-09-12 12:19:00  903.62   110
# 4576  581581  17581.0 2011-09-12 12:20:00   51.18   110
# 4577  581582  17581.0 2011-09-12 12:21:00   29.88   110
# 4578  581585  15804.0 2011-09-12 12:31:00  329.05   110
#
# [4579 rows x 5 columns]

# %%
# 按【用户 ID】分组后，获取【时间间隔】列的最小值、【订单号】列的数量以及【总金额】列的总和
rfm_data = grouped_data.groupby(by='用户 ID', as_index=False).agg({'时间间隔':'min','订单号':'count','总金额':'sum'})
rfm_data
# Out:
#         用户 ID  时间间隔  订单号       总金额
# 0     12346.0   347    1  77183.60
# 1     12349.0    40    1   1757.55
# 2     12352.0    94    8   2506.04
# 3     12359.0    30    4   6357.73
# 4     12360.0    74    3   2662.06
# ...       ...   ...  ...       ...
# 1084  18250.0   332    1    349.27
# 1085  18251.0   109    1   4314.72
# 1086  18270.0   288    2    283.15
# 1087  18277.0    21    1    110.38
# 1088  18287.0    21    3   1837.28
#
# [1089 rows x 4 columns]

# %%
# 修改列名为：用户 ID、时间间隔、总次数和总金额
rfm_data.columns = ['用户 ID', '时间间隔', '总次数', '总金额']
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额
# 0     12346.0   347    1  77183.60
# 1     12349.0    40    1   1757.55
# 2     12352.0    94    8   2506.04
# 3     12359.0    30    4   6357.73
# 4     12360.0    74    3   2662.06
# ...       ...   ...  ...       ...
# 1084  18250.0   332    1    349.27
# 1085  18251.0   109    1   4314.72
# 1086  18270.0   288    2    283.15
# 1087  18277.0    21    1    110.38
# 1088  18287.0    21    3   1837.28
#
# [1089 rows x 4 columns]

# %%
# 画 R 值（时间间隔）的折线图，便于后续对数据进行分组
plt.figure(figsize=(10, 8))
x = rfm_data['时间间隔'].sort_values()
y = rfm_data.index
plt.plot(x, y)

# %%
# 定义函数按照区间划分 R 值
def caculate_r(s):
    if s <= 100:
        return 5
    elif s <= 200:
        return 4
    elif s <= 300:
        return 3
    elif s <= 400:
        return 2
    else:
        return 1

# 对 R 值进行评分
rfm_data['R评分'] = rfm_data['时间间隔'].agg(caculate_r)
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额  R评分
# 0     12346.0   347    1  77183.60    2
# 1     12349.0    40    1   1757.55    5
# 2     12352.0    94    8   2506.04    5
# 3     12359.0    30    4   6357.73    5
# 4     12360.0    74    3   2662.06    5
# ...       ...   ...  ...       ...  ...
# 1084  18250.0   332    1    349.27    2
# 1085  18251.0   109    1   4314.72    4
# 1086  18270.0   288    2    283.15    3
# 1087  18277.0    21    1    110.38    5
# 1088  18287.0    21    3   1837.28    5
#
# [1089 rows x 5 columns]

# %%
# 画 F 值（总次数）的折线图，便于后续对数据进行分组
plt.figure(figsize=(10, 8))
x = rfm_data['总次数'].sort_values()
y = rfm_data.index
plt.plot(x, y)

# %%
# 定义函数按照区间划分 F 值
def caculate_f(s):
    if s <= 5:
        return 1
    elif s <= 10:
        return 2
    elif s <= 15:
        return 3
    elif s <= 20:
        return 4
    else:
        return 5
# 对 F 值进行评分
rfm_data['F评分'] = rfm_data['总次数'].agg(caculate_f)
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额  R评分  F评分
# 0     12346.0   347    1  77183.60    2    1
# 1     12349.0    40    1   1757.55    5    1
# 2     12352.0    94    8   2506.04    5    2
# 3     12359.0    30    4   6357.73    5    1
# 4     12360.0    74    3   2662.06    5    1
# ...       ...   ...  ...       ...  ...  ...
# 1084  18250.0   332    1    349.27    2    1
# 1085  18251.0   109    1   4314.72    4    1
# 1086  18270.0   288    2    283.15    3    1
# 1087  18277.0    21    1    110.38    5    1
# 1088  18287.0    21    3   1837.28    5    1
#
# [1089 rows x 6 columns]

# %%
# 画 M 值（总金额）的折线图，便于后续对数据进行分组
plt.figure(figsize=(10, 8))
x = rfm_data['总金额'].sort_values()
y = rfm_data.index
plt.plot(x, y)

# %%
# 定义函数按照区间划分 M 值
def caculate_m(s):
    if s <= 2000:
        return 1
    elif s <= 4000:
        return 2
    elif s <= 6000:
        return 3
    elif s <= 8000:
        return 4
    else:
        return 5

# 对 M 值进行评分
rfm_data['M评分'] = rfm_data['总金额'].agg(caculate_m)
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额  R评分  F评分  M评分
# 0     12346.0   347    1  77183.60    2    1    5
# 1     12349.0    40    1   1757.55    5    1    1
# 2     12352.0    94    8   2506.04    5    2    2
# 3     12359.0    30    4   6357.73    5    1    4
# 4     12360.0    74    3   2662.06    5    1    2
# ...       ...   ...  ...       ...  ...  ...  ...
# 1084  18250.0   332    1    349.27    2    1    1
# 1085  18251.0   109    1   4314.72    4    1    3
# 1086  18270.0   288    2    283.15    3    1    1
# 1087  18277.0    21    1    110.38    5    1    1
# 1088  18287.0    21    3   1837.28    5    1    1
#
# [1089 rows x 7 columns]

# %%
# 计算 R评分、F评分、M评分的平均数
r_avg = rfm_data['R评分'].mean()
f_avg = rfm_data['F评分'].mean()
m_avg = rfm_data['M评分'].mean()

print('R评分的均值为：{}，F评分的均值为{}，M评分的均值为{}'.format(r_avg, f_avg, m_avg))
# Out:
# R评分的均值为：4.2442607897153355，F评分的均值为1.3489439853076217，M评分的均值为1.376492194674013

# %%
# 将R评分、F评分、M评分 的数据分别与对应的平均数做比较
rfm_data['R评分'] = (rfm_data['R评分'] > r_avg) * 1
rfm_data['F评分'] = (rfm_data['F评分'] > f_avg) * 1
rfm_data['M评分'] = (rfm_data['M评分'] > m_avg) * 1
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额  R评分  F评分  M评分
# 0     12346.0   347    1  77183.60    0    0    1
# 1     12349.0    40    1   1757.55    1    0    0
# 2     12352.0    94    8   2506.04    1    1    1
# 3     12359.0    30    4   6357.73    1    0    1
# 4     12360.0    74    3   2662.06    1    0    1
# ...       ...   ...  ...       ...  ...  ...  ...
# 1084  18250.0   332    1    349.27    0    0    0
# 1085  18251.0   109    1   4314.72    0    0    1
# 1086  18270.0   288    2    283.15    0    0    0
# 1087  18277.0    21    1    110.38    1    0    0
# 1088  18287.0    21    3   1837.28    1    0    0
#
# [1089 rows x 7 columns]

# %%
# 拼接R评分、F评分、M评分
rfm_score = rfm_data['R评分'].astype(str) + rfm_data['F评分'].astype(str) + rfm_data['M评分'].astype(str)
rfm_score
# Out:
# 0       001
# 1       100
# 2       111
# 3       101
# 4       101
#        ...
# 1084    000
# 1085    001
# 1086    000
# 1087    100
# 1088    100
# Length: 1089, dtype: object

# %%
# 定义字典标记 RFM 评分档对应的用户分类名称
transform_label = {
    '111':'重要价值用户',
    '101':'重要发展用户',
    '011':'重要保持用户',
    '001':'重要挽留用户',
    '110':'一般价值用户',
    '100':'一般发展用户',
    '010':'一般保持用户',
    '000':'一般挽留用户'
}
# 将 RFM 评分替换成具体的客户类型
rfm_data['客户类型'] = rfm_score.replace(transform_label)
rfm_data
# Out:
#         用户 ID  时间间隔  总次数       总金额  R评分  F评分  M评分    客户类型
# 0     12346.0   347    1  77183.60    0    0    1  重要挽留用户
# 1     12349.0    40    1   1757.55    1    0    0  一般发展用户
# 2     12352.0    94    8   2506.04    1    1    1  重要价值用户
# 3     12359.0    30    4   6357.73    1    0    1  重要发展用户
# 4     12360.0    74    3   2662.06    1    0    1  重要发展用户
# ...       ...   ...  ...       ...  ...  ...  ...     ...
# 1084  18250.0   332    1    349.27    0    0    0  一般挽留用户
# 1085  18251.0   109    1   4314.72    0    0    1  重要挽留用户
# 1086  18270.0   288    2    283.15    0    0    0  一般挽留用户
# 1087  18277.0    21    1    110.38    1    0    0  一般发展用户
# 1088  18287.0    21    3   1837.28    1    0    0  一般发展用户
#
# [1089 rows x 8 columns]

# %%
# 按【客户类型】分组，统计用户的数量
customer_data = rfm_data.groupby('客户类型')['用户 ID'].count()
customer_data
# Out:
# 客户类型
# 一般价值用户     48
# 一般保持用户      7
# 一般发展用户    395
# 一般挽留用户    414
# 重要价值用户    150
# 重要保持用户     15
# 重要发展用户     33
# 重要挽留用户     27
# Name: 用户 ID, dtype: int64

# %%
# 绘制柱状图
plt.figure(figsize=(12, 8))
plt.bar(customer_data.index, customer_data)
plt.xlabel('客户类型', fontsize=12)
plt.ylabel('人数', fontsize=12)
plt.title('不同客户的数量分布', fontsize=16)
# Out:
# Text(0.5, 1.0, '不同客户的数量分布')

# %%
# 绘制饼图
plt.figure(figsize=(14, 10))
plt.pie(customer_data, labels=customer_data.index, autopct='%0.1f%%')
plt.title('不同客户占比情况', fontsize=16)
# Out:
# Text(0.5, 1.0, '不同客户占比情况')

# %%
# df.map() 方法

# 某男子私立大学三名延毕学生数据
df_7 = pd.DataFrame({'姓名': ['零某某', '徐放牛', '文学'],
                    '性别': ['男', '男', '男'],
                    '专业': ['生物信息', '人工智能', '电子竞技'],
                    '挂科次数': ['7', '5', '4'],
                    '旷课次数': [45, 44, 30],
                    '总次数': [52, 49, 34]})
# 先定义一个函数
def map_judge(x):
    if x >= 50:
        return "开除"
    else:
        return "延毕"

# 将函数 map_judge 作为参数传入 df.map()
df_7['总次数'] = df_7['总次数'].map(map_judge)

# 查看数据
df_7
# Out:
#     姓名 性别    专业 挂科次数  旷课次数 总次数
# 0  零某某  男  生物信息    7    45  开除
# 1  徐放牛  男  人工智能    5    44  延毕
# 2   文学  男  电子竞技    4    30  延毕
